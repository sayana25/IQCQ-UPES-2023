# %% [markdown]
# <a href="https://colab.research.google.com/github/sayana25/IQCQ-UPES-2023/blob/main/Bloch_Visualisation_and_QuantumFourierTransform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 13.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 27.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 12.4 MB/s eta 0:00:00
# ...

# %%
# !pip install pylatexenc
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136816 sha256=9fc458b0700f30b119d453a97163e253ce7d27cd96c7cdbf4ce02c8994f530f5
#   Stored in directory: /root/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# ...

# %%
pip install qiskit-aer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 25.5 MB/s eta 0:00:00
# ...

# %%
pip install qiskit-ibm-runtime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 21.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 6.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 16.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 13.5 MB/s eta 0:00:00
# ...

# %%
pip install qiskit-ibm-provider
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 2.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 6.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# Change of Basis from computational to Hadamard Basis and their corresponding visualisation. After that we go to the circuit for the **Quantum Fourier Transform**.
#
#
# The quantum Fourier transform (QFT) transforms between two bases, the computational (Z) basis, and the Fourier basis. Hadamard is the single-qubit QFT, and it transforms between the Z-basis states
#  and
#  to the X-basis states
#  and. The QFT is simply the function that transforms between these bases. For higher number of qubits we will look into the circuit diagram.

# %%
import numpy as np
from numpy import pi
# importing Qiskit
from qiskit import QuantumCircuit, transpile, Aer, IBMQ, assemble
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from math import pi, sqrt
sim = Aer.get_backend('aer_simulator')

# %% [markdown]
# Let's at first have some visualization of Bloch vectors on the Bloch sphere using Qiskit

# %%
# Let's do an X-gate on a |0> qubit
qc = QuantumCircuit(1)
qc.x(0)
qc.draw('mpl')

# %%
# Let's see the result
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)
# Out:
# <ipython-input-13-a1a96e5a2882>:4: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   state = sim.run(qobj).result().get_statevector()

# %%
# Let's do an Y-gate on a |0> qubit
qc = QuantumCircuit(1)
#qc.x(0)
qc.y(0)
qc.draw('mpl')

# %%
# Let's see the result
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)
# Out:
# <ipython-input-19-a1a96e5a2882>:4: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   state = sim.run(qobj).result().get_statevector()

# %%
# Let's do an Y-gate on a |1> qubit
qc = QuantumCircuit(1)
#In qiskit, the qubit is initialised at |0>
qc.x(0) #prepares the |1> qubit
qc.y(0) #Then y-gate is applied on y
qc.draw('mpl')

# %%
# Let's see the result
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)
# Out:
# <ipython-input-22-a1a96e5a2882>:4: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   state = sim.run(qobj).result().get_statevector()

# %% [markdown]
# **The Z gate and the computational basis**
#
#
# Z-gate appears to have no effect on our qubit when it is in either of these two states. This is because the states $|0\rangle $ and $|1\rangle$ are the two eigenstates of the Z-gate. In fact, the computational basis (the basis formed by these two states) is often called the Z-basis.
#
#
# https://github.com/Qiskit/textbook/blob/main/notebooks/ch-states/single-qubit-gates.ipynb

# %%
# Let's do an Y-gate on a |1> qubit
qc = QuantumCircuit(1)
#In qiskit, the qubit is initialised at |0>
qc.z(0) #z rotation on the |0> qubit, leaves it unchanged as seen below
qc.draw('mpl')

# Let's see the result
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)
# <ipython-input-23-222d64b181a8>:10: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   state = sim.run(qobj).result().get_statevector()

# %% [markdown]
# **The effect of the Hadamard gate on the states $|0\rangle$ and $|1\rangle$**
#
# The creation of the $|+\rangle$ and $|-\rangle$ by applying the Hadamard gate on the $|0\rangle$ and $|1\rangle$ states thus creating the fourier/Hadamard basis.
#
# Thus Hadamard is the 1-qubit QFT.

# %%
# Let's do an Y-gate on a |1> qubit
qc = QuantumCircuit(1)
#In qiskit, the qubit is initialised at |0>
qc.x(0)
qc.z(0) #z rotation on the |1> qubit?
qc.draw('mpl')

# Let's see the result
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)
# <ipython-input-24-a87d35bceaa5>:11: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   state = sim.run(qobj).result().get_statevector()

# %%
# Let's do an H-gate on a |0> qubit
qc = QuantumCircuit(1)
#In qiskit, the qubit is initialised at |0>
qc.h(0)
qc.draw('mpl')

# Let's see the result
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)
# <ipython-input-26-41a0180d3f41>:10: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   state = sim.run(qobj).result().get_statevector()

# %%
# Let's do an H-gate on a |0> qubit followed by Z
qc = QuantumCircuit(1)
#In qiskit, the qubit is initialised at |0>, let's convert it to the |1> state
qc.h(0)
qc.z(0)


# Let's see the result
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)
# Out:
# <ipython-input-29-ce93d14d4017>:11: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   state = sim.run(qobj).result().get_statevector()

# %%
# Let's do an H-gate on a |0> qubit followed by X
qc = QuantumCircuit(1)
#In qiskit, the qubit is initialised at |0>, let's convert it to the |1> state
qc.h(0)
qc.x(0) #Does this make any difference?
qc.z(0) #This flips


# Let's see the result
qc.save_statevector()
qobj = assemble(qc)
state = sim.run(qobj).result().get_statevector()
plot_bloch_multivector(state)
# Out:
# <ipython-input-31-fe134fe629ab>:12: DeprecationWarning: Using a qobj for run() is deprecated as of qiskit-aer 0.9.0 and will be removed no sooner than 3 months from that release date. Transpiled circuits should now be passed directly using `backend.run(circuits, **run_options).
#   state = sim.run(qobj).result().get_statevector()

# %% [markdown]
# The quantum Fourier transform (QFT) is the quantum implementation of the discrete Fourier transform over the amplitudes of a wavefunction. It is a significant step in many quantum algorithms, most notably Shor's factoring algorithm and quantum phase estimation. The quantum Fourier transform acts on a quantum state $|X\rangle = \sum\limits_{j = 0}^{N-1}x_{j}|j\rangle$ mapping it to the quantum state $|Y\rangle = \sum\limits_{j = 0}^{N-1}y_{k}|k\rangle$ according to the formula,
#
# $y_{k} =\frac{1}{\sqrt{N}}\sum\limits_{j = 0}^{N-1} x_{j}e^{2\pi i \frac{jk}{N}}$. This transformation could infact be represented by an unitary matrix,
# $U_{QFT} = \frac{1}{\sqrt{N}} \sum\limits_{j = 0}^{N-1}\sum\limits_{k = 0}^{N-1} e^{2\pi i \frac{jk}{N}} |k\rangle\langle j|$.
#
# For implementing the QFT circuit, two gates are required, the Hadamard and the two-qubit controlled rotation $CROT_{k}$ gate. In QISKIT this is represented by the $CP(\theta)$.

# %% [markdown]
# Contains the details of QFT for 3 and higher number of qubits :https://github.com/Qiskit/textbook/blob/main/notebooks/ch-algorithms/quantum-fourier-transform.ipynb

# %% [markdown]
# **4-qubit QFT**
#
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
from numpy import pi
# importing Qiskit
from qiskit import QuantumCircuit, transpile, Aer, IBMQ
from qiskit.tools.monitor import job_monitor
from qiskit.visualization import plot_histogram, plot_bloch_multivector

# %% [markdown]
# **3-qubit QFT**

# %%
qc = QuantumCircuit(3)
qc.h(2)
qc.cp(pi/2, 1, 2) # CROT from qubit 1 to qubit 2
qc.cp(pi/4, 0, 2) # CROT from qubit 2 to qubit 0
qc.h(1)
qc.cp(pi/2, 0, 1) # CROT from qubit 0 to qubit 1
qc.h(0)
qc.swap(0,2)
qc.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %% [markdown]
# **General number of qubits in the QFT**, shown for 4 qubits in the example

# %%
def qft_rotations(circuit, n):
    """Performs qft on the first n qubits in circuit (without swaps)"""
    if n == 0:
        return circuit
    n -= 1
    circuit.h(n)
    for qubit in range(n):
        circuit.cp(pi/2**(n-qubit), qubit, n)
    # At the end of our function, we call the same function again on
    # the next qubits (we reduced n by one earlier in the function)
    qft_rotations(circuit, n)

# Let's see how it looks:
qc = QuantumCircuit(4)
qft_rotations(qc,4)
qc.draw('mpl')

# %% [markdown]
# Full circuit with the **SWAP-gate**

# %%
def swap_registers(circuit, n):
    for qubit in range(n//2):
        circuit.swap(qubit, n-qubit-1)
    return circuit

def qft(circuit, n):
    """QFT on the first n qubits in circuit"""
    qft_rotations(circuit, n)
    swap_registers(circuit, n)
    return circuit

# Let's see how it looks:
qc = QuantumCircuit(4)
qft(qc,4)
qc.draw('mpl')

# %% [markdown]
# **Checking if the QFT circuit works properly**

# %%
bin(5)
# Out:
# '0b101'

# %% [markdown]
# *Note that QISKIT uses little endian approach, meaning that the topmost qubit q0 is the least significant*

# %% [markdown]
# **Now let us check if our QFT circuit works properly and for that we take the input 6, in the binary form and create it using qiskit**

# %%
# Create the circuit
qc = QuantumCircuit(3)

# Encode the state 5
qc.x(0)
qc.x(2)
qc.draw('mpl')

# %%
#Checking qubit states in the bloch vector representation using the Aer simulator

sim = Aer.get_backend("aer_simulator")
qc_init = qc.copy()
qc_init.save_statevector()
statevector = sim.run(qc_init).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
qft(qc,3)
qc.draw('mpl')

# %% [markdown]
# the x gates encodes the inputs into the circuit in the computational basis.

# %%
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)

# %% [markdown]
# For more details please go through : https://github.com/Qiskit/textbook/blob/main/notebooks/ch-algorithms/quantum-fourier-transform.ipynb and https://learning.quantum.ibm.com/course/fundamentals-of-quantum-algorithms/phase-estimation-and-factoring#quantum-fourier-transform

# %% [markdown]
# Another example? Let's take the number 4!

# %%
bin(4)
# Out:
# '0b100'

# %%
# Create the circuit
qc = QuantumCircuit(3)

# Encode the state 4
qc.x(2)
qc.draw('mpl')

# %%
sim = Aer.get_backend("aer_simulator")
qc_init = qc.copy()
qc_init.save_statevector()
statevector = sim.run(qc_init).result().get_statevector()
plot_bloch_multivector(statevector)

# %%
qft(qc,3)
qc.draw('mpl')

# %%
qc.save_statevector()
statevector = sim.run(qc).result().get_statevector()
plot_bloch_multivector(statevector)
