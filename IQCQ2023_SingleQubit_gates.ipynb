# %% [markdown]
# <a href="https://colab.research.google.com/github/sayana25/IQCQ-UPES-2023/blob/main/IQCQ2023_SingleQubit_gates.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install qiskit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 16.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 32.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.4/39.4 MB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 13.0 MB/s eta 0:00:00
# ...

# %%
pip install qiskit-ibm-runtime
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.7/229.7 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 7.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.9/243.9 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.9/57.9 kB 6.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 130.2/130.2 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.6/104.6 kB 11.0 MB/s eta 0:00:00
# ...

# %%
# !pip install pylatexenc
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 3.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=136816 sha256=2532b10a27e7dafb76276aa9c3cf551cfd9dbaad78dd7fddac84c9d18d82dd11
#   Stored in directory: /root/.cache/pip/wheels/d3/31/8b/e09b0386afd80cfc556c00408c9aeea5c35c4d484a9c762fd5
# Successfully built pylatexenc
# ...

# %%
# !pip install matplotlib

# %%
# !pip install matplotlib-venn

# %%
import qiskit
from qiskit import QuantumCircuit,QuantumRegister,ClassicalRegister,execute,IBMQ,  assemble, Aer
from qiskit.visualization import plot_histogram, plot_bloch_vector
from math import sqrt, pi

#qc = QuantumCircuit(1) # Create a quantum circuit with one qubit

qc = QuantumCircuit(1)  # Create a quantum circuit with one qubit
initial_state = [0,1]   # Define initial_state as |1>
qc.initialize(initial_state, 0) # Apply initialisation operation to the 0th qubit
qc.draw()  # Let's view our circuit
# Out:
#    ┌─────────────────┐
# q: ┤ Initialize(0,1) ├
#    └─────────────────┘

# %%
qc = QuantumCircuit(3,3)  # Create a quantum circuit with 3 qubits, like in python
qc.h(0) #hadamard gate
qc.x(1) #Pauli-X gate
qc.y(2) #Pauli-Y gate
qc.draw()  # Let's view our circuit
# Out:
#      ┌───┐
# q_0: ┤ H ├
#      ├───┤
# q_1: ┤ X ├
#      ├───┤
# q_2: ┤ Y ├
#      └───┘
# c: 3/═════

# %%
qc = QuantumCircuit(3,3)  # Create a quantum circuit with 3 qubits, like in python
qc.h(0) #hadamard gate
qc.x(1) #Pauli-X gate
qc.y(2) #Pauli-Y gate
qc.measure_all()
# Let's view our circuit
qc.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
import qiskit
from qiskit import QuantumCircuit,QuantumRegister,ClassicalRegister,execute,IBMQ,  assemble, Aer
from qiskit.visualization import plot_histogram, plot_bloch_vector
from math import sqrt, pi

# %%
X = QuantumRegister(1, "Alice") #naming the qubit
#naming the qubit
circuit = QuantumCircuit(X)
circuit.h(X)
circuit.s(X)
circuit.h(X)
circuit.t(X)
circuit.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister

X = QuantumRegister(1, "x")
Y = QuantumRegister(1, "y")
A = ClassicalRegister(1, "a")
B = ClassicalRegister(1, "b")

circuit = QuantumCircuit(Y, X, B, A)
circuit.h(Y)
circuit.cx(Y, X)
circuit.measure(Y, B)
circuit.measure(X, A)

display(circuit.draw('mpl'))

# %% [markdown]
# **The Pauli X,Y,Z Gates**

# %%
qc = QuantumCircuit(4)
qc.x(0)
qc.y(1) # Qubit number inside the bracket, as in python the counting starts from 0
qc.z(2)
qc.barrier
qc.y(0)
qc.z(0)
qc.draw('mpl')
# Out:
# /usr/local/lib/python3.10/dist-packages/qiskit/visualization/circuit/matplotlib.py:266: FutureWarning: The default matplotlib drawer scheme will be changed to "iqp" in a following release. To silence this warning, specify the current default explicitly as style="clifford", or the new default as style="iqp".
#   self._style, def_font_ratio = load_style(self._style)

# %% [markdown]
# **Creating the bell state circuit: $|\phi^{+}\rangle$**

# %%
bell = QuantumCircuit(2)

bell.h(0) # apply an H gate to the circuit
bell.cx(0,1) # apply a CNOT gate to the circuit

bell.draw(output="mpl")

# %%
import numpy as np

# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile, assemble, Aer, IBMQ, execute
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector, plot_histogram

# %% [markdown]
# By default, states in qiskit start in $|0\rangle$, which corresponds to "arrow up" on the Bloch sphere. "Bit Flip" corresponds to the $|0\rangle → |1\rangle$

# %%
def bitflip():
    qc = QuantumCircuit(1)
    qc.x(0)
    return qc

state = Statevector.from_instruction(bitflip())
plot_bloch_multivector(state)

# %% [markdown]
# The superposition state is reached by the application of the hadamard gate : $|+\rangle = \frac{1}{\sqrt{2}}\left(|0\rangle + |1\rangle\right)$, shown below.

# %%
def superposition():
    qc = QuantumCircuit(1)
    qc.h(0)
    return qc

state = Statevector.from_instruction(superposition())
plot_bloch_multivector(state)

# %% [markdown]
# qc.x(0), **rotation by Pi around the x-axis** \\
# qc.y(0),  **rotation by Pi around the y-axis** \\
# qc.z(0),  **rotation by Pi around the z-axis** \\
# qc.s(0),    **rotation by Pi/2 around the z-axis** \\
# qc.sdg(0),  **rotation by -Pi/2 around the z-axis** \\
# qc.h(0),    **rotation by Pi around an axis located halfway between x and z**

# %% [markdown]
# How to reach the state $|-\rangle = \frac{1}{\sqrt{2}}\left(|0\rangle - |1\rangle\right)$ ?

# %%
def antisuperposition():
    qc = QuantumCircuit(1)
    qc.h(0)
    qc.z(0) #phase flip
    return qc

state = Statevector.from_instruction(antisuperposition())
plot_bloch_multivector(state)

# %% [markdown]
# How to reach the state $|- i\rangle = \frac{1}{\sqrt{2}}\left(|0\rangle - i|1\rangle\right)$ ?

# %%
def complex():
    qc = QuantumCircuit(1)
    qc.h(0)
    qc.sdg(0)
    return qc

state = Statevector.from_instruction(complex())
plot_bloch_multivector(state)
